# %%
import numpy as np
import pandas as pd

# %%
data = {
    'Name' : ['John', 'Anna', 'Peter', 'Linda'],
    'Age' : [28,32,59,22],
    'City': ['New York', 'London','Paris', 'Berlin'],
    'Salary': [64000,43000,23000,66000]
}
df = pd.DataFrame(data)

# %%
df
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   64000
# 1   Anna   32    London   43000
# 2  Peter   59     Paris   23000
# 3  Linda   22    Berlin   66000

# %%
data_list = [
    ['John', 'Anna', 'Peter', 'Linda'],
     [28,32,59,22],
    ['New York', 'London','Paris', 'Berlin'],
    [64000,43000,23000,66000]
]

dl = pd.DataFrame(data_list)
# indexing
col = ['Name','Age','City','Random']
dl = pd.DataFrame(data_list,columns=col)
dl
# Out:
#        Name     Age   City  Random
# 0      John    Anna  Peter   Linda
# 1        28      32     59      22
# 2  New York  London  Paris  Berlin
# 3     64000   43000  23000   66000

# %%
# selecting Rows/Cols

# %%
dl[['Name','Age']]
# Out:
#        Name     Age
# 0      John    Anna
# 1        28      32
# 2  New York  London
# 3     64000   43000

# %%
dl.loc[[0,1]]
# Out:
#    Name   Age   City Random
# 0  John  Anna  Peter  Linda
# 1    28    32     59     22

# %%
# Add column in the table

# %%
dl['Random'] = ['aa','asda','ada','ad']

# %%
dl
# Out:
#        Name     Age   City Random
# 0      John    Anna  Peter     aa
# 1        28      32     59   asda
# 2  New York  London  Paris    ada
# 3     64000   43000  23000     ad

# %%
# removing a row/column

# %%
dl.drop('Random',axis = 1)
# Out:
#        Name     Age   City
# 0      John    Anna  Peter
# 1        28      32     59
# 2  New York  London  Paris
# 3     64000   43000  23000

# %%
dl
# Out:
#        Name     Age   City Random
# 0      John    Anna  Peter     aa
# 1        28      32     59   asda
# 2  New York  London  Paris    ada
# 3     64000   43000  23000     ad

# %%
dl.drop('Random',axis=1,inplace=True)

# %%
dl
# Out:
#        Name     Age   City
# 0      John    Anna  Peter
# 1        28      32     59
# 2  New York  London  Paris
# 3     64000   43000  23000

# %%
dl.drop(0,axis=0)
# Out:
#        Name     Age   City
# 1        28      32     59
# 2  New York  London  Paris
# 3     64000   43000  23000

# %%
dl
# Out:
#        Name     Age   City
# 0      John    Anna  Peter
# 1        28      32     59
# 2  New York  London  Paris
# 3     64000   43000  23000

# %%
# Selecting a subset of rows/column

# %%
df
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   64000
# 1   Anna   32    London   43000
# 2  Peter   59     Paris   23000
# 3  Linda   22    Berlin   66000

# %%
df.loc[[2,3]][['Name','Age']]
# Out:
#     Name  Age
# 2  Peter   59
# 3  Linda   22

# %%
# Conditional Selection

# %%
df
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   64000
# 1   Anna   32    London   43000
# 2  Peter   59     Paris   23000
# 3  Linda   22    Berlin   66000

# %%
df[df['Age'] < 30]
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   64000
# 3  Linda   22    Berlin   66000

# %%
df[(df['Age'] < 30) & (df['City'] == 'Berlin')]
# Out:
#     Name  Age    City  Salary
# 3  Linda   22  Berlin   66000
